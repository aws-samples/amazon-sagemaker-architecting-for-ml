# %% [markdown]
# Title: Books on Tape - Author Classification from Dante and Shakespeare
#
# Given a line from either Shakespeare or Dante, we will train a machine learning model that will accurately predict the author.
#
# We will investigate three candidate models and compare their performance: Amazon’s BlazingText, Naive Bayes, and KNeighbors.
#
# We have chosen two scenes from the Merchant of Venice by William Shakespeare and two scenes from the Divine Comedy by Dante Alighieri. These scenes will be transcribed using Amazon Transcribe. Word transcription data will then be processed and cleaned. Transcriptions with low confidence will be evaluated for removal. Data will then be explored and formatted.
#
# Formatted data will be used to train models and features selected. A second set of data will be chosen for and processed for validation. Each model’s performance will be evaluated and compared.
#
# Questions we are now considering/ Interesting thoughts:
# 1. How well can Amazon Transcribe transcribe the unique language of Shakespeare? Will transcriptions with low confidence turn out to be revealing language for classifying authors?
# 2. Shakespeare is written in iambic pentameter. Dante is originally written in Terza Rima and often translated into iambic pentameter. Is meter a revealing feature for author classification?  Can meter be used as a feature?
# 3. Features of interest - words common by one author or another; uniqueness as a feature; clusters of words; semantics as a feature - Dante will have a lot of “fiery, hell, burning”

# %%
import sagemaker
from sagemaker import get_execution_role
import json
import boto3
from __future__ import print_function
import time

# %%
#transcribe chapters function
def transcribe_chapters (job_name, job_uri): 
    transcribe = boto3.client('transcribe')
    output_bucket = bucket
    transcribe.start_transcription_job(
        TranscriptionJobName=job_name,
        Media={'MediaFileUri': job_uri},
        MediaFormat='mp3',
        LanguageCode='en-US',
        OutputBucketName=output_bucket
    )
    while True:
        status = transcribe.get_transcription_job(TranscriptionJobName=job_name)
        if status['TranscriptionJob']['TranscriptionJobStatus'] in ['COMPLETED', 'FAILED']:
            break
        print("Not ready yet...")
        time.sleep(5)
    print(status)
    # !aws transcribe list-transcription-jobs
    # !aws transcribe delete-transcription-job --transcription-job-name $job_name

# %%
#set session variables
sess = sagemaker.Session()

role = get_execution_role()
print(role) # This is the role that SageMaker would use to leverage AWS resources (S3, CloudWatch) on your behalf

bucket = 'crazycurlygirlbucket311' # Replace with your own bucket name if needed
print(bucket)
prefix = 'BookProphet' #Replace with the prefix under which you want to store the data if needed
# Out:
# arn:aws:iam::023375022819:role/service-role/AmazonSageMaker-ExecutionRole-20181029T121824
# crazycurlygirlbucket311

# %%
# get the files
#!wget https://etc.usf.edu/lit2go/audio/mp3/the-merchant-of-venice-005-merchant-of-venice-act-2-scene-1.589.mp3
#!wget https://etc.usf.edu/lit2go/audio/mp3/the-merchant-of-venice-014-merchant-of-venice-act-3-scene-1.600.mp3

# !wget http://www.archive.org/download/romeo_and_juliet_librivox/Romeo_and_Juliet_Act_3.mp3
# !wget http://www.archive.org/download/romeo_and_juliet_librivox/Romeo_and_Juliet_Act_5.mp3
# !wget https://etc.usf.edu/lit2go/76/the-tragedy-of-julius-caesar/1249/act-2-scene-4/

# !wget http://www.archive.org/download/divine_comedy_librivox/divinecomedy_longfellow_14_dante.mp3   
:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.1’
#
# index.html.1            [ <=>                ]  13.71K  --.-KB/s    in 0s
#
# 2019-03-14 18:38:17 (151 MB/s) - ‘index.html.1’ saved [14040]
#
# --2019-03-14 18:38:17--  http://www.archive.org/download/divine_comedy_librivox/divinecomedy_longfellow_14_dante.mp3
# Resolving www.archive.org (www.archive.org)... 207.241.224.2
# Connecting to www.archive.org (www.archive.org)|207.241.224.2|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: http://archive.org/download/divine_comedy_librivox/divinecomedy_longfellow_14_dante.mp3 [following]
# --2019-03-14 18:38:17--  http://archive.org/download/divine_comedy_librivox/divinecomedy_longfellow_14_dante.mp3
# Resolving archive.org (archive.org)... 207.241.224.2
# Reusing existing connection to www.archive.org:80.
# HTTP request sent, awaiting response... 302 Found
# Location: http://ia800201.us.archive.org/3/items/divine_comedy_librivox/divinecomedy_longfellow_14_dante.mp3 [following]
# --2019-03-14 18:38:19--  http://ia800201.us.archive.org/3/items/divine_comedy_librivox/divinecomedy_longfellow_14_dante.mp3
# Resolving ia800201.us.archive.org (ia800201.us.archive.org)... 207.241.230.21
# Connecting to ia800201.us.archive.org (ia800201.us.archive.org)|207.241.230.21|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39490598 (38M) [audio/mpeg]
# Saving to: ‘divinecomedy_longfellow_14_dante.mp3.1’
#
# divinecomedy_longfe 100%[===================>]  37.66M  1.26MB/s    in 39s
#
# 2019-03-14 18:38:57 (997 KB/s) - ‘divinecomedy_longfellow_14_dante.mp3.1’ saved [39490598/39490598]

# %%
# save MP3 files to S3
MP3Location = prefix + '/MP3Files'

#sess.upload_data(path='the-merchant-of-venice-005-merchant-of-venice-act-2-scene-1.589.mp3', bucket=bucket, key_prefix=MP3Location)
#sess.upload_data(path='the-merchant-of-venice-014-merchant-of-venice-act-3-scene-1.600.mp3', bucket=bucket, key_prefix=MP3Location)
#sess.upload_data(path='divinecomedy_longfellow_05_dante.mp3', bucket=bucket, key_prefix=MP3Location)
#sess.upload_data(path='divinecomedy_longfellow_10_dante.mp3', bucket=bucket, key_prefix=MP3Location)

sess.upload_data(path='Romeo_and_Juliet_Act_3.mp3', bucket=bucket, key_prefix=MP3Location)
sess.upload_data(path='Romeo_and_Juliet_Act_5.mp3', bucket=bucket, key_prefix=MP3Location)
sess.upload_data(path='divinecomedy_longfellow_14_dante.mp3', bucket=bucket, key_prefix=MP3Location)
#sess.upload_data(path='', bucket=bucket, key_prefix=MP3Location)
# Out:
# 's3://crazycurlygirlbucket311/BookProphet/MP3Files/divinecomedy_longfellow_14_dante.mp3'

# %%
#create dictionary of job names and uri
# chapters = {
#     "merchant1": "s3://crazycurlygirlbucket311/BookProphet/MP3Files/the-merchant-of-venice-005-merchant-of-venice-act-2-scene-1.589.mp3",
#     "merchant2": "s3://crazycurlygirlbucket311/BookProphet/MP3Files/the-merchant-of-venice-014-merchant-of-venice-act-3-scene-1.600.mp3",
#     "divine1": "s3://crazycurlygirlbucket311/BookProphet/MP3Files/divinecomedy_longfellow_05_dante.mp3",
#     "divine2": "s3://crazycurlygirlbucket311/BookProphet/MP3Files/divinecomedy_longfellow_10_dante.mp3" 
# }

chapters = {
    'rom1': "s3://crazycurlygirlbucket311/BookProphet/MP3Files/Romeo_and_Juliet_Act_3.mp3",
    'rom2': "s3://crazycurlygirlbucket311/BookProphet/MP3Files/Romeo_and_Juliet_Act_5.mp3",
    'paradise': "s3://crazycurlygirlbucket311/BookProphet/MP3Files/divinecomedy_longfellow_14_dante.mp3"
}

# %%
# transcribe chapters using function
for ch, uri in chapters.items():
    transcribe_chapters(ch,uri)
# Out:
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# {'TranscriptionJob': {'TranscriptionJobName': 'rom1', 'TranscriptionJobStatus': 'COMPLETED', 'LanguageCode': 'en-US', 'MediaSampleRateHertz': 44100, 'MediaFormat': 'mp3', 'Media': {'MediaFileUri': 's3://crazycurlygirlbucket311/BookProphet/MP3Files/Romeo_and_Juliet_Act_3.mp3'}, 'Transcript': {'TranscriptFileUri': 'https://s3.amazonaws.com/crazycurlygirlbucket311/rom1.json'}, 'CreationTime': datetime.datetime(2019, 3, 14, 18, 45, 28, 915000, tzinfo=tzlocal()), 'CompletionTime': datetime.datetime(2019, 3, 14, 18, 52, 32, 912000, tzinfo=tzlocal()), 'Settings': {'ChannelIdentification': False}}, 'ResponseMetadata': {'RequestId': '55aa838d-468a-11e9-89af-8372e5ff8d2b', 'HTTPStatusCode': 200, 'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1', 'date': 'Thu, 14 Mar 2019 18:52:36 GMT', 'x-amzn-requestid': '55aa838d-468a-11e9-89af-8372e5ff8d2b', 'content-length': '470', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {
#     "TranscriptionJobSummaries": [
#         {
#             "TranscriptionJobName": "rom1",
#             "CreationTime": 1552589128.915,
#             "CompletionTime": 1552589552.912,
#             "LanguageCode": "en-US",
#             "TranscriptionJobStatus": "COMPLETED",
#             "OutputLocationType": "CUSTOMER_BUCKET"
#         }
#     ]
# }
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# {'TranscriptionJob': {'TranscriptionJobName': 'rom2', 'TranscriptionJobStatus': 'COMPLETED', 'LanguageCode': 'en-US', 'MediaSampleRateHertz': 44100, 'MediaFormat': 'mp3', 'Media': {'MediaFileUri': 's3://crazycurlygirlbucket311/BookProphet/MP3Files/Romeo_and_Juliet_Act_5.mp3'}, 'Transcript': {'TranscriptFileUri': 'https://s3.amazonaws.com/crazycurlygirlbucket311/rom2.json'}, 'CreationTime': datetime.datetime(2019, 3, 14, 18, 52, 38, 820000, tzinfo=tzlocal()), 'CompletionTime': datetime.datetime(2019, 3, 14, 18, 57, 24, 242000, tzinfo=tzlocal()), 'Settings': {'ChannelIdentification': False}}, 'ResponseMetadata': {'RequestId': '03c5e555-468b-11e9-b61e-551a6003dee0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1', 'date': 'Thu, 14 Mar 2019 18:57:28 GMT', 'x-amzn-requestid': '03c5e555-468b-11e9-b61e-551a6003dee0', 'content-length': '469', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {
#     "TranscriptionJobSummaries": [
#         {
#             "TranscriptionJobName": "rom2",
#             "CreationTime": 1552589558.82,
#             "CompletionTime": 1552589844.242,
#             "LanguageCode": "en-US",
#             "TranscriptionJobStatus": "COMPLETED",
#             "OutputLocationType": "CUSTOMER_BUCKET"
#         }
#     ]
# }
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# Not ready yet...
# {'TranscriptionJob': {'TranscriptionJobName': 'paradise', 'TranscriptionJobStatus': 'COMPLETED', 'LanguageCode': 'en-US', 'MediaSampleRateHertz': 44100, 'MediaFormat': 'mp3', 'Media': {'MediaFileUri': 's3://crazycurlygirlbucket311/BookProphet/MP3Files/divinecomedy_longfellow_14_dante.mp3'}, 'Transcript': {'TranscriptFileUri': 'https://s3.amazonaws.com/crazycurlygirlbucket311/paradise.json'}, 'CreationTime': datetime.datetime(2019, 3, 14, 18, 57, 30, 620000, tzinfo=tzlocal()), 'CompletionTime': datetime.datetime(2019, 3, 14, 19, 5, 37, 875000, tzinfo=tzlocal()), 'Settings': {'ChannelIdentification': False}}, 'ResponseMetadata': {'RequestId': '27b6fc4f-468c-11e9-8182-73bfea3c5474', 'HTTPStatusCode': 200, 'HTTPHeaders': {'content-type': 'application/x-amz-json-1.1', 'date': 'Thu, 14 Mar 2019 19:05:38 GMT', 'x-amzn-requestid': '27b6fc4f-468c-11e9-8182-73bfea3c5474', 'content-length': '487', 'connection': 'keep-alive'}, 'RetryAttempts': 0}}
# {
#     "TranscriptionJobSummaries": [
#         {
#             "TranscriptionJobName": "paradise",
#             "CreationTime": 1552589850.62,
#             "CompletionTime": 1552590337.875,
#             "LanguageCode": "en-US",
#             "TranscriptionJobStatus": "COMPLETED",
#             "OutputLocationType": "CUSTOMER_BUCKET"
#         }
#     ]
# }

# %%
# #copy transcribe results to notebook for future reference
# !aws s3 cp s3://crazycurlygirlbucket311/divine1.json divine1.json
# !aws s3 cp s3://crazycurlygirlbucket311/divine2.json divine2.json
# !aws s3 cp s3://crazycurlygirlbucket311/merchant1.json merchant1.json
# !aws s3 cp s3://crazycurlygirlbucket311/merchant2.json merchant2.json
    
# !aws s3 cp s3://crazycurlygirlbucket311/rom1.json rom1.json
# !aws s3 cp s3://crazycurlygirlbucket311/rom2.json rom2.json
# !aws s3 cp s3://crazycurlygirlbucket311/paradise.json paradise.json
# Out:
# download: s3://crazycurlygirlbucket311/rom1.json to ./rom1.json
# download: s3://crazycurlygirlbucket311/rom2.json to ./rom2.json
# download: s3://crazycurlygirlbucket311/paradise.json to ./paradise.json
